# %% [markdown]
# # Challenge 2

# %% [markdown]
# In this lab you will partner with another student to conduct **[pair programming](https://en.wikipedia.org/wiki/Pair_programming)**. In the next 60 minutes there will be 2 coding sessions of 30 minutes each. In each sessoin, one student will be the **driver** to write the code to solve the problem while the other student will be the **observer** to watch and review. There will be several iterations of your code because the observer will help the driver review the codes and make improvements until the 15 minute session ends. After the coding session ends, the driver and observer will switch roles.

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Preparation
#
# #### Import the `Fitbit2.csv` file and name your dataset `fitbit`

# %%
fitbit=pd.read_csv('Fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
fitbit.shape
# Out:
# (367, 24)

# %%
for col in fitbit.columns:
    print(col)
# Out:
# Date
# Calorie burned
# Steps
# Distance
# Floors
# Minutes Sedentary
# Minutes Lightly Active
# Minutes Fairly Active
# Minutes Very Active
# Activity Calories
# MinutesOfSleep
# MinutesOfBeingAwake
# NumberOfAwakings
# LengthOfRestInMinutes
# Distance_miles
# Days
# Days_encoded
# Work_or_Weekend
# Hours Sleep
# Sleep efficiency
# Yesterday_sleep
# Yesterday_sleep_efficiency
# Months
# Months_encoded

# %% [markdown]
# ## Coding Session I - 30 minutes
#
# From the Fitbit data, we want to visually understand:
#
# 1. **How the average number of steps change by month. Use the appropriate visualization to show the median steps by month?**
# 1. **Is Fitbitter more active on weekend or workdays?**
#
# ##### All plots must be in the same jupyter notebook cell.
#
# Hints:
#
# - Use `Months_encoded` and `Week_or Weekend` columns
# - Use `matplolib.pyplot` object oriented API
# - Set your size figure to `12,4`
# - Explore `plt.sca`
# - Explore `plt.xticks`
# - Save your figures

# %%
# Driver 1 enter codes here
# Aquí saco la media total solo por curiosidad

Steps_ave = fitbit['Steps'].mean()
Steps_ave
# Out:
# 10121.58855585831

# %%
# Agrupo por mes y hago la media de todas las columnas

grouped_months = fitbit.groupby('Months_encoded')
mean_by_months = grouped_months.mean()
mean_by_months
# Out:
#                 Calorie burned         Steps   Distance     Floors  \
# Months_encoded
# 1                  2812.806452   9892.064516   7.912581   8.580645
# 2                  2600.100000   8922.866667   7.143667   9.666667
# 3                  2281.258065  10312.935484   9.184194   9.935484
# 4                  3030.800000  13079.033333  11.190667  11.566667
# 5                  2836.580645  10620.096774   8.799677  10.741935
# 6                  2971.666667  12536.166667  10.881667  24.366667
# 7                  2699.935484   9193.322581   8.695484  16.000000
# 8                  2844.967742  11584.774194   9.059677  14.129032
# 9                  2908.000000   9191.333333   7.836333  12.266667
# 10                 2608.838710   8272.451613   6.570000   6.709677
# 11                 2578.066667   9467.466667   7.927333   8.033333
# 12                 2737.290323   8470.064516   7.460323   8.935484
#
#                 Minutes Sedentary  Minutes Lightly Active  \
# Months_encoded
# ...

# %%
# Saco solo la columna de 'Steps'

mean_steps = grouped_months['Steps'].mean()
mean_steps
# Out:
# Months_encoded
# 1      9892.064516
# 2      8922.866667
# 3     10312.935484
# 4     13079.033333
# 5     10620.096774
# 6     12536.166667
# 7      9193.322581
# 8     11584.774194
# 9      9191.333333
# 10     8272.451613
# 11     9467.466667
# 12     8470.064516
# Name: Steps, dtype: float64

# %%
f, ax = plt.subplots()

x = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre']
l = mean_steps.index
y = mean_steps.values

ax.bar(l,y)
ax.set_xticks(l)
ax.set_xticklabels(x, rotation='vertical')

plt.show()

# %%
# Hacemos la misma operación pero agrupando por días

grouped_weekdays = fitbit.groupby('Days_encoded')
mean_by_weekdays = grouped_weekdays.mean()
mean_by_weekdays
# Out:
#               Calorie burned         Steps  Distance     Floors  \
# Days_encoded
# 0.0              2696.480769   9949.615385  8.366538  13.461538
# 1.0              2816.711538  10043.884615  8.592115  13.423077
# 2.0              2806.115385  10769.288462  8.966731  15.000000
# 3.0              2824.461538   9999.557692  8.892115  14.403846
# 4.0              2752.851852   9967.333333  8.677407  12.092593
# 5.0              2643.150943  11551.792453  9.160943   6.471698
# 6.0              2652.192308   8548.076923  7.171346   7.307692
#
#               Minutes Sedentary  Minutes Lightly Active  \
# Days_encoded
# 0.0                  586.454269              217.500000
# 1.0                  585.720481              208.173077
# 2.0                  578.132173              224.403846
# 3.0                  556.202962              224.807692
# 4.0                  579.410519              252.000000
# 5.0                  541.411189              293.905660
# ...

# %%
mean_weekdays = grouped_weekdays['Steps'].mean()
mean_weekdays
# Out:
# Days_encoded
# 0.0     9949.615385
# 1.0    10043.884615
# 2.0    10769.288462
# 3.0     9999.557692
# 4.0     9967.333333
# 5.0    11551.792453
# 6.0     8548.076923
# Name: Steps, dtype: float64

# %%
f, ax = plt.subplots()

x = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday','Sunday']
l = mean_weekdays.index
y = mean_weekdays.values

ax.bar(l,y)
ax.set_xticks(l)
ax.set_xticklabels(x, rotation='vertical')

plt.show()

# %% [markdown]
# Como conclusión sacamos que el sábado es el día que más pasos se dan en toda la semana, y el domingo, efectivamente, es el día que menos

# %% [markdown]
# ## Coding Session II - 30 minutes
#
# **Write a loop to plot 3 scatter plots of the following features:**
#
# 1. **`Minutes Lightly Active`  vs `Steps`**
# 1. **`Minutes Very Active` vs `Steps`**
# 1. **`Minutes Sedentary` vs `Steps`**

# %%
# Driver 2 enter codes here

# %%
#Primero imprimo por separado para comprobar que van funcionando

plot1 = fitbit.plot('Minutes Lightly Active', 'Steps', kind="scatter", figsize = (4,8), alpha = 0.8)
plt.show()

# %%
plot2 = fitbit.plot('Minutes Very Active', 'Steps', kind="scatter", figsize = (4,8), alpha = 0.8)
plt.show()

# %%
plot3 = fitbit.plot('Minutes Sedentary', 'Steps', kind="scatter", figsize = (4,8), alpha = 0.8)
plt.show()

# %%
# Aqui el For Loop para que salgan juntas, con un subplots

cols=['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary','Steps']
df=fitbit[cols]
fig,axes = plt.subplots(figsize = (16,8), nrows = 1, ncols = 3)
for i in range(3):
    plt.sca(axes[i])
    plt.scatter(df.iloc[:,i],df['Steps'], alpha = 0.8)
    plt.xlabel(df.iloc[:,i].name)
    plt.ylabel('Steps')
