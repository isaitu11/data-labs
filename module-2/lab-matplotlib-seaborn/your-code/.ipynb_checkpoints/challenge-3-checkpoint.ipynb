# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.shape
# Out:
# (1309, 12)

# %%
#Compruebo que no hay ningun Id repetido

unique_id = titanic['PassengerId'].unique()
unique_id
# Out:
# array([   1,    2,    3, ..., 1307, 1308, 1309])

# %%
#Sobrevivieron más mujeres que hombres
grouped_gender = titanic.groupby('Gender')
sex_survived_mean = grouped_gender['Survived'].mean()
sex_survived_mean
# Out:
# Gender
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
grouped_gender = titanic.groupby('Gender')
age_survived_mean = grouped_gender['Age'].mean()
age_survived_mean
# Out:
# Gender
# female    28.548826
# male      30.614592
# Name: Age, dtype: float64

# %%
# La persona más anciana
titanic['Age'].max()
# Out:
# 80.0

# %%
# La persona más anciana
oldest_info = titanic[titanic['Age'] == 80.0]
oldest_info
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631       1.0       1  Barkworth, Mr. Algernon Henry Wilson
#
#     Gender   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630   male  80.0      0      0  27042  30.0   A23        S

# %%
# La persona más joven
titanic['Age'].min()
# Out:
# 0.17

# %%
youngest_info = titanic[titanic['Age'] == 0.17]
youngest_info
# Out:
#       PassengerId  Survived  Pclass                                     Name  \
# 1245         1246       NaN       3  Dean, Miss. Elizabeth Gladys Millvina""
#
#       Gender   Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 1245  female  0.17      1      2  C.A. 2315  20.575    U0        S

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
num_variables = titanic.select_dtypes(include=['float64','int64'], exclude=['object'])
num_variables.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
from pandas import Series, DataFrame

# %%
#your code here- categorical variable
cat_variables = pd.Series(['Survived', 'Pclass', 'SibSp', 'Parch'],dtype="category")
cat_variables
# Out:
# 0    Survived
# 1      Pclass
# 2       SibSp
# 3       Parch
# dtype: category
# Categories (4, object): [Parch, Pclass, SibSp, Survived]

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic')
sns.set_style('white')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# He creado tantas barras como edades
titanic['Age'].hist(bins=80)

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.subplot(1,3,1)
titanic['Age'].hist(bins=10)
plt.subplot(1,3,2)
titanic['Age'].hist(bins=20)
plt.subplot(1,3,3)
titanic['Age'].hist(bins=50)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %% [markdown]
# #your comment here
# Yes, the more bins, the more information

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'],bins=80)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic['Gender'].value_counts().plot(kind='bar')

# %%
# your code here- 2nd way
sns.countplot(x='Gender',data=titanic)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
grouped_pclass = titanic.groupby('Pclass')
pclass_count= grouped_pclass['PassengerId'].count()
pclass_count
# Out:
# Pclass
# 1    323
# 2    277
# 3    709
# Name: PassengerId, dtype: int64

# %%
titanic['Pclass'].value_counts().plot(kind='bar')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
titanic.boxplot(column='Age')

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
#That the mean is around 30 years old, and there is a little people between 60 and 80 years old.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
titanic['Age'].hist(bins=50)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
titanic.plot('Fare', 'Age', kind="scatter", figsize = (4,8), alpha = 0.8)
plt.show()

# %%
# your code-2nd way
sns.distplot(titanic['Fare'])
sns.distplot(titanic['Age']);

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here

sns.heatmap(titanic.corr())

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here

#your code here
sns.boxplot(x='Pclass',y='Age',data=titanic,palette='rainbow')

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(data=titanic,col='Gender')
g.map(plt.hist,'Age')
