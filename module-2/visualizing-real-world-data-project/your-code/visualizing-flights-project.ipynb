# %% [markdown]
# # visualizing real world data project

# %%
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline

# %%
tickets = pd.read_csv('../flights_tickets_serp2018-12-16.csv')
tickets.head()
# Out:
#             searchTerms  rank  \
# 0  flights to hong kong     1
# 1  flights to hong kong     2
# 2  flights to hong kong     3
# 3  flights to hong kong     4
# 4  flights to hong kong     5
#
#                                                title  \
# 0  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1  $480 Flights to Hong Kong, China (HKG) - TripA...
# 2  Cheap Flights to Hong Kong International from ...
# 3  Flights to Hong Kong (HKG) | Hong Kong Flight ...
# 4  Cheap Flights to Hong Kong SAR, Asia $393.97 i...
#
#                                              snippet  \
# 0  Find flights to Hong Kong on XiamenAir, Hong K...
# 1  Cheap Flights to Hong Kong: Enter your dates o...
# 2  Search cheap flights using Skyscanner's free f...
# 3  Find & book great deals on Hong Kong (HKG) Fli...
# 4  Expedia Add-On Advantage: Book a flight & unlo...
#
#                  displayLink  \
# 0              www.kayak.com
# 1        www.tripadvisor.com
# 2         www.skyscanner.com
# ...

# %%
tickets.shape
# Out:
# (4000, 26)

# %%
tickets.drop(['cacheId','pagemap','gl','formattedUrl','inputEncoding','safe','cx','outputEncoding','htmlSnippet','htmlTitle', 'cseName'], axis=1, inplace=True)

# %%
tickets.shape
# Out:
# (4000, 15)

# %%
tickets.head()
# Out:
#             searchTerms  rank  \
# 0  flights to hong kong     1
# 1  flights to hong kong     2
# 2  flights to hong kong     3
# 3  flights to hong kong     4
# 4  flights to hong kong     5
#
#                                                title  \
# 0  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1  $480 Flights to Hong Kong, China (HKG) - TripA...
# 2  Cheap Flights to Hong Kong International from ...
# 3  Flights to Hong Kong (HKG) | Hong Kong Flight ...
# 4  Cheap Flights to Hong Kong SAR, Asia $393.97 i...
#
#                                              snippet  \
# 0  Find flights to Hong Kong on XiamenAir, Hong K...
# 1  Cheap Flights to Hong Kong: Enter your dates o...
# 2  Search cheap flights using Skyscanner's free f...
# 3  Find & book great deals on Hong Kong (HKG) Fli...
# 4  Expedia Add-On Advantage: Book a flight & unlo...
#
#                  displayLink  \
# 0              www.kayak.com
# 1        www.tripadvisor.com
# 2         www.skyscanner.com
# ...

# %%
tickets.drop(['link', 'htmlFormattedUrl', 'kind', 'count', 'formattedSearchTime', 'formattedTotalResults'], axis=1, inplace=True)

# %%
tickets.shape
# Out:
# (4000, 9)

# %%
tickets.head()
# Out:
#             searchTerms  rank  \
# 0  flights to hong kong     1
# 1  flights to hong kong     2
# 2  flights to hong kong     3
# 3  flights to hong kong     4
# 4  flights to hong kong     5
#
#                                                title  \
# 0  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1  $480 Flights to Hong Kong, China (HKG) - TripA...
# 2  Cheap Flights to Hong Kong International from ...
# 3  Flights to Hong Kong (HKG) | Hong Kong Flight ...
# 4  Cheap Flights to Hong Kong SAR, Asia $393.97 i...
#
#                                              snippet  \
# 0  Find flights to Hong Kong on XiamenAir, Hong K...
# 1  Cheap Flights to Hong Kong: Enter your dates o...
# 2  Search cheap flights using Skyscanner's free f...
# 3  Find & book great deals on Hong Kong (HKG) Fli...
# 4  Expedia Add-On Advantage: Book a flight & unlo...
#
#                  displayLink                         queryTime  totalResults  \
# ...

# %%
tickets['startIndex'].unique()
# Out:
# array([1])

# %%
tickets.drop(['startIndex'], axis=1, inplace=True)

# %%
tickets.head()
# Out:
#             searchTerms  rank  \
# 0  flights to hong kong     1
# 1  flights to hong kong     2
# 2  flights to hong kong     3
# 3  flights to hong kong     4
# 4  flights to hong kong     5
#
#                                                title  \
# 0  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1  $480 Flights to Hong Kong, China (HKG) - TripA...
# 2  Cheap Flights to Hong Kong International from ...
# 3  Flights to Hong Kong (HKG) | Hong Kong Flight ...
# 4  Cheap Flights to Hong Kong SAR, Asia $393.97 i...
#
#                                              snippet  \
# 0  Find flights to Hong Kong on XiamenAir, Hong K...
# 1  Cheap Flights to Hong Kong: Enter your dates o...
# 2  Search cheap flights using Skyscanner's free f...
# 3  Find & book great deals on Hong Kong (HKG) Fli...
# 4  Expedia Add-On Advantage: Book a flight & unlo...
#
#                  displayLink                         queryTime  totalResults  \
# ...

# %%
displayLink_unique = tickets['displayLink'].unique()
len(displayLink_unique)
# Out:
# 271

# %%
searchTerms_unique = tickets['searchTerms'].unique()
len(searchTerms_unique)
# Out:
# 200

# %%
searchTerms_unique
# Out:
# array(['flights to hong kong', 'flights to bangkok', 'flights to london',
#        'flights to singapore', 'flights to macau', 'flights to dubai',
#        'flights to paris', 'flights to new york city',
#        'flights to shenzhen', 'flights to kuala lumpur',
#        'flights to phuket', 'flights to delhi', 'flights to tokyo',
#        'flights to rome', 'flights to taipei', 'flights to guangzhou',
#        'flights to mumbai', 'flights to mecca', 'flights to istanbul',
#        'flights to prague', 'flights to miami', 'flights to seoul',
#        'flights to barcelona', 'flights to pattaya',
#        'flights to shanghai', 'flights to milan', 'flights to cancún',
#        'flights to agra', 'flights to las vegas', 'flights to amsterdam',
#        'flights to antalya', 'flights to denpasar', 'flights to osaka',
#        'flights to los angeles', 'flights to vienna', 'flights to berlin',
#        'flights to madrid', 'flights to johor bahru',
# ...

# %%
split = tickets['searchTerms'].str.split("flights to", expand=True)
split1 = split[0].str.split("tickets to", expand=True)

# %%
Destinies = split[0] + split[1]
Destinies
# Out:
# 0        hong kong
# 1        hong kong
# 2        hong kong
# 3        hong kong
# 4        hong kong
# 5        hong kong
# 6        hong kong
# 7        hong kong
# 8        hong kong
# 9        hong kong
# 10         bangkok
# 11         bangkok
# 12         bangkok
# 13         bangkok
# 14         bangkok
# 15         bangkok
# 16         bangkok
# 17         bangkok
# 18         bangkok
# 19         bangkok
# 20          london
# 21          london
# 22          london
# 23          london
# 24          london
# 25          london
# 26          london
# 27          london
# 28          london
# 29          london
#            ...
# 3970           NaN
# 3971           NaN
# 3972           NaN
# 3973           NaN
# 3974           NaN
# 3975           NaN
# 3976           NaN
# 3977           NaN
# 3978           NaN
# 3979           NaN
# 3980           NaN
# 3981           NaN
# 3982           NaN
# 3983           NaN
# 3984           NaN
# 3985           NaN
# ...

# %%
tickets['searchTerms'] = Destinies
tickets
# Out:
#      searchTerms  rank                                              title  \
# 0      hong kong     1  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1      hong kong     2  $480 Flights to Hong Kong, China (HKG) - TripA...
# 2      hong kong     3  Cheap Flights to Hong Kong International from ...
# 3      hong kong     4  Flights to Hong Kong (HKG) | Hong Kong Flight ...
# 4      hong kong     5  Cheap Flights to Hong Kong SAR, Asia $393.97 i...
# 5      hong kong     6  Cheap Flights to Hong Kong - Search Deals on A...
# 6      hong kong     7       Flights to Hong Kong SAR (HKG) on Orbitz.com
# 7      hong kong     8  Passenger Arrivals, Flights - Hong Kong Intern...
# 8      hong kong     9  Fly Hong Kong Airlines | Flights To & From Hon...
# 9      hong kong    10  Find Cheap Flights to Hong Kong from 395 USD |...
# 10       bangkok     1  $454 Flights to Bangkok, Thailand (BKK) - Trip...
# 11       bangkok     2  Cheap Flights to Bangkok, Bangkok $376.23 in 2...
# ...

# %%
grouped_dest = tickets.groupby('searchTerms').agg()
grouped_dest
# Out:
#                     rank  title  snippet  displayLink  queryTime  \
# searchTerms
#  abu dhabi            20     20       20           20         20
#  agra                 20     20       20           20         20
#  amsterdam            20     20       20           20         20
#  antalya              20     20       20           20         20
#  artvin               20     20       20           20         20
#  athens               20     20       20           20         20
#  auckland             20     20       20           20         20
#  bangkok              20     20       20           20         20
#  barcelona            20     20       20           20         20
#  beijing              20     20       20           20         20
#  berlin               20     20       20           20         20
#  brussels             20     20       20           20         20
#  budapest             20     20       20           20         20
# ...
