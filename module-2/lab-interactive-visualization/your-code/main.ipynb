# %% [markdown]
# # Interactive Visualization Lab
#
# Complete the following set of exercises to solidify your knowledge of interactive visualization using Plotly, Cufflinks, and IPyWidgets.

# %%
import pandas as pd
import numpy as np
import plotly.plotly as py
import cufflinks as cf
from ipywidgets import interact

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_excel('./../data/Online Retail.xlsx')

# %%
data.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396034 entries, 0 to 396033
# Data columns (total 9 columns):
# InvoiceNo      396034 non-null int64
# InvoiceDate    396034 non-null datetime64[ns]
# StockCode      396034 non-null object
# Description    396034 non-null object
# Quantity       396034 non-null int64
# UnitPrice      396034 non-null float64
# Revenue        396034 non-null float64
# CustomerID     396034 non-null int64
# Country        396034 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 27.2+ MB

# %%
data["InvoiceDate"].dt.month.head()
data["InvoiceDate"].dt.year.head()
# Out:
# 0    2010
# 1    2010
# 2    2010
# 3    2010
# 4    2010
# Name: InvoiceDate, dtype: int64

# %% [markdown]
# ## 1. Create an interactive bar chart showing total quantity and revenue by country (excluding United Kingdom) for the month of April 2011.

# %%
by_country = data[(data["Country"]!='United Kingdom')&(data["InvoiceDate"].dt.month==4)&(data["InvoiceDate"].dt.year==2011)].pivot_table(index=["Country"], values=["Quantity", "Revenue"], aggfunc={"Quantity":np.sum, "Revenue":np.sum})
by_country

by_country.iplot(kind='bar', xTitle='Value',
           yTitle='Count', title='Quantity & Revenue by Country')
# Out:
# <div>
#
#
#             <div id="65756d63-8292-4037-8391-b8d911f55aee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("65756d63-8292-4037-8391-b8d911f55aee")) {
#                     Plotly.newPlot(
#                         '65756d63-8292-4037-8391-b8d911f55aee',
# ...

# %% [markdown]
# ## 2. Create an interactive line chart showing quantity and revenue sold to France between January 1st and May 31st 2011.

# %%
france_by_datetime = data[(data["Country"]=='France')&(data["InvoiceDate"].dt.month<=5)&(data["InvoiceDate"].dt.year==2011)].pivot_table(index=["InvoiceDate"], values=["Quantity", "Revenue"], aggfunc={"Quantity":np.sum, "Revenue":np.sum})
france_by_datetime

france_by_datetime.iplot(kind='line', xTitle='January 1st - May 31st 2011',
           yTitle='Count', title='Quantity & Revenue France')
# Out:
# <div>
#
#
#             <div id="d038ab94-99e7-4a7f-bae9-646e3b191628" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d038ab94-99e7-4a7f-bae9-646e3b191628")) {
#                     Plotly.newPlot(
#                         'd038ab94-99e7-4a7f-bae9-646e3b191628',
# ...

# %% [markdown]
# ## 3. Create an interactive scatter plot showing the relationship between average quantity (x-axis) and average unit price (y-axis) for the product PARTY BUNTING with the plot points color-coded by country (categories).

# %%
party_bunting = data[(data["Description"]=='PARTY BUNTING')].pivot_table(index=["Country"], values=["Quantity", "UnitPrice"], aggfunc={"Quantity":np.mean, "UnitPrice":np.mean})
party_bunting.head()
# Out:
#                   Quantity  UnitPrice
# Country
# Australia        33.125000     4.7125
# Austria           8.000000     4.9500
# Belgium           4.000000     4.9500
# Channel Islands  13.333333     4.9500
# Cyprus            2.333333     4.7500

# %%
party_bunting.iplot(x='Quantity', y='UnitPrice', 
           xTitle='UnitPrice', yTitle='Total Quantity',
           title='Dont know')
# Out:
# <div>
#
#
#             <div id="2a1bd283-70ea-47ab-8362-cee14d39f225" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2a1bd283-70ea-47ab-8362-cee14d39f225")) {
#                     Plotly.newPlot(
#                         '2a1bd283-70ea-47ab-8362-cee14d39f225',
# ...

# %%
party_bunting.iplot(x='Quantity', y='UnitPrice', categories='Country'
           xTitle='UnitPrice', yTitle='Total Quantity',
           title='Dont know')
# Out:
#   File "<ipython-input-23-ec1c038410fb>", line 2
#     xTitle ='UnitPrice', yTitle='Total Quantity',
#          ^
# SyntaxError: invalid syntax

# %%
party_bunting.iplot(x='tenure', y='TotalCharges', categories='InternetService',
           xTitle='Tenure', yTitle='Total Charges',
           title='Charges vs. Tenure: One Year Contract, Credit Card Customers')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'InternetService'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-d30987c3455b> in <module>
# ...

# %% [markdown]
# ## 4. Create a set of interactive histograms showing the distributions of quantity per invoice for the following countries: EIRE, Germany, France, and Netherlands.

# %% [markdown]
# ## 5. Create an interactive side-by-side bar chart showing the revenue by country listed below (bars) for each of the products listed below.

# %%
product_list = ['JUMBO BAG RED RETROSPOT', 
                'CREAM HANGING HEART T-LIGHT HOLDER',
                'REGENCY CAKESTAND 3 TIER']

country_list = ['EIRE', 'Germany', 'France', 'Netherlands']

# %% [markdown]
# ## 6. Create an interactive line chart showing quantity sold by day for the United Kingdom. Add drop-down boxes for Year and Month that allow you to filter the date range that appears in the chart.

# %%
data['Year'] = pd.DatetimeIndex(data['InvoiceDate']).year
data['Month'] = pd.DatetimeIndex(data['InvoiceDate']).month
data['Day'] = pd.DatetimeIndex(data['InvoiceDate']).day
uk = data[data['Country']=='United Kingdom']

# %% [markdown]
# ## 7. Create an interactive scatter plot that plots number of invoices (x-axis) vs. number of customers (y-axis) and the plot points represent individual products. Add two sliders that control the x and y axis ranges.

# %%
agg_func = {'InvoiceNo':'nunique',
            'Quantity':'sum',
            'UnitPrice':'mean',
            'Revenue':'sum',
            'CustomerID':'nunique'}

products = uk.groupby('Description').agg(agg_func)

# %% [markdown]
# ## 8. Creat an interactive bar chart that shows revenue by product description. Add a text field widget that filters the results to show the product that contain the text entered in their description.
