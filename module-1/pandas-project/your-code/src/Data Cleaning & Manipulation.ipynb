# %%
# Importamos pandas

import pandas as pd
pd.set_option('display.max_columns',50)

# %%
# Leemos el archivo 'CSV' con ayuda de un 'encoding'
# '../input' para indicar la nueva ruta del 'CSV'

shark_df = pd.read_csv('../input/GSAF5.csv', encoding = 'iso8859_15')

# %%
shark_df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male    M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  NaN
# 4                       Bells Beach  Surfing             male    M  NaN
#
#                                   Injury Fatal (Y/N)   Time   Species   \
# ...

# %%
# this returns a tuple of the dimensions of the dataframe
shark_df.shape
# Out:
# (5992, 24)

# %%
# this returns the datatypes of the columns
shark_df.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# Unnamed: 22               object
# Unnamed: 23               object
# dtype: object

# %%
# although the datatype for 'Injury' appears to be object, further
# investigation shows it's a string
type(shark_df['Injury'][0])
# Out:
# str

# %%
# Copia por si acaso
shark_df_aux = shark_df.copy

# %%
# PAra ver cuales tienen espacios
shark_df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
shark_df.fillna('.', inplace=True)

# %%
# this displays a concise summary of the dataframe,
# including the number of non-null values in each column
shark_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5992 entries, male to male
# Data columns (total 23 columns):
# Case Number               5992 non-null object
# Date                      5992 non-null object
# Year                      5992 non-null int64
# Type                      5992 non-null object
# Country                   5992 non-null object
# Area                      5992 non-null object
# Location                  5992 non-null object
# Activity                  5992 non-null object
# Sex                       5992 non-null object
# Age                       5992 non-null object
# Injury                    5992 non-null object
# Fatal (Y/N)               5992 non-null object
# Time                      5992 non-null object
# Species                   5992 non-null object
# Investigator or Source    5992 non-null object
# pdf                       5992 non-null object
# href formula              5992 non-null object
# href                      5992 non-null object
# ...

# %%
# this returns the number of unique values in each column
shark_df.nunique()
# Out:
# Case Number               5976
# Date                      5128
# Year                       232
# Type                         6
# Country                    204
# Area                       786
# Location                  3930
# Activity                  1492
# Sex                          6
# Age                        152
# Injury                    3596
# Fatal (Y/N)                  9
# Time                       358
# Species                   1539
# Investigator or Source    4753
# pdf                       5981
# href formula              5981
# href                      5973
# Case Number.1             5975
# Case Number.2             5976
# original order            5988
# Unnamed: 22                  2
# Unnamed: 23                  3
# dtype: int64

# %%
shark_df['Fatal (Y/N)'].value_counts()
# Out:
# N          4315
# Y          1552
# UNKNOWN      94
# .            19
#  N            8
# #VALUE!       1
# F             1
# N             1
# n             1
# Name: Fatal (Y/N), dtype: int64

# %%
shark_df['Fatal (Y/N)'] = shark_df['Fatal (Y/N)'].replace("Y", True).replace("F", True)
shark_df['Fatal (Y/N)'].value_counts()
# Out:
# N          4315
# True       1553
# UNKNOWN      94
# .            19
#  N            8
# #VALUE!       1
# N             1
# n             1
# Name: Fatal (Y/N), dtype: int64

# %%
shark_df_filtered = shark_df[shark_df['Country']== 'SPAIN']

# %%
print(shark_df_filtered)
# Out:
#                                       Case Number                  Date  Year  \
# Name
# male                                   2016.07.29             29-Jul-16  2016
# female                               2016.07.08.R  Reported 08-Jul-2016  2016
# Cristina Ojeda-Thies                   2015.12.25             25-Dec-15  2015
# male                                 2015.08.18.a             18-Aug-15  2015
# male                                 2014.12.03.R  Reported 03-Dec-2014  2014
# male                                   2014.09.00                Sep-14  2014
# Raquel Martin                        2014.08.27.c             27-Aug-14  2014
# child                                  2014.07.20             20-Jul-14  2014
# Thierry Frennet                        2013.07.09             07-Jul-13  2013
# male                                 2010.07.16.b             16-Jul-10  2010
# NaN                                  2009.07.24.a             24-Jul-09  2009
# ...

# %%
df_aux_filtered= df_aux[df_aux['Country']== 'SPAIN' ]

# %%
# this returns useful descriptive statistics for each column of data
shark_df.describe()
# Out:
#               Year  original order
# count  5992.000000     5992.000000
# mean   1925.204606     2997.548899
# std     286.473712     1729.860210
# min       0.000000        2.000000
# 25%    1942.000000     1499.750000
# 50%    1975.000000     2997.500000
# 75%    2003.000000     4495.250000
# max    2016.000000     5993.000000

# %%
# this returns returns the last few rows
shark_df.tail(2)
# Out:
#      Case Number       Date  Year        Type             Country  \
# 5990     ND.0002  1883-1889     0  Unprovoked              PANAMA
# 5991     ND.0001  1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                   Area                             Location  Activity  \
# 5990               NaN                 Panama Bay 8ºN, 79ºW       NaN
# 5991  Eastern Province  Below the English fort, Trincomalee  Swimming
#
#                  Name Sex   Age  \
# 5990  Jules Patterson    M  NaN
# 5991             male    M   15
#
#                                                  Injury Fatal (Y/N) Time  \
# 5990                                              FATAL        True  NaN
# 5991  FATAL. "Shark bit him in half, carrying away t...        True  NaN
#
#      Species  Investigator or Source                         pdf  \
# 5990      NaN    The Sun, 10/20/1938  ND-0002-JulesPatterson.pdf
# 5991      NaN             S.W. Baker          ND-0001-Ceylon.pdf
#
# ...

# %%
# View the index number and label for each column
for i, v in enumerate(shark_df.columns):
    print(i, v)
# Out:
# 0 Case Number
# 1 Date
# 2 Year
# 3 Type
# 4 Country
# 5 Area
# 6 Location
# 7 Activity
# 8 Name
# 9 Sex
# 10 Age
# 11 Injury
# 12 Fatal (Y/N)
# 13 Time
# 14 Species
# 15 Investigator or Source
# 16 pdf
# 17 href formula
# 18 href
# 19 Case Number.1
# 20 Case Number.2
# 21 original order
# 22 Unnamed: 22
# 23 Unnamed: 23

# %%
# select all the columns from 'id' to the last mean column
shark_df_1 = shark_df.loc[:,'Year':'Injury']
shark_df_1.head()
# Out:
#    Year        Type    Country      Area                          Location  \
# 0  2016  Unprovoked        USA   Florida  New Smyrna Beach, Volusia County
# 1  2016  Unprovoked        USA   Florida  New Smyrna Beach, Volusia County
# 2  2016  Unprovoked        USA   Florida  New Smyrna Beach, Volusia County
# 3  2016  Unprovoked  AUSTRALIA  Victoria                  Thirteenth Beach
# 4  2016  Unprovoked  AUSTRALIA  Victoria                       Bells Beach
#
#   Activity             Name Sex   Age                                 Injury
# 0  Surfing             male    M   16                  Minor injury to thigh
# 1  Surfing   Chucky Luciano    M   36                   Lacerations to hands
# 2  Surfing             male    M   43               Lacerations to lower leg
# 3  Surfing  Rory Angiolella    M  NaN           Struck by fin on chest & leg
# 4  Surfing             male    M  NaN  No injury: Knocked off board by shark

# %%
# repeat the step above using index numbers
shark_df = shark_df.iloc[:,:11]
shark_df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   Age
# 0  New Smyrna Beach, Volusia County  Surfing             male    M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male    M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  NaN
# 4                       Bells Beach  Surfing             male    M  NaN

# %%
shark_df = pd.read_csv('../input/GSAF5.csv', encoding = 'iso8859_15', index_col='Name')
shark_df.head()
# Out:
#                   Case Number       Date  Year        Type    Country  \
# Name
# male             2016.09.18.c  18-Sep-16  2016  Unprovoked        USA
# Chucky Luciano   2016.09.18.b  18-Sep-16  2016  Unprovoked        USA
# male             2016.09.18.a  18-Sep-16  2016  Unprovoked        USA
# Rory Angiolella    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA
# male               2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA
#
#                      Area                          Location Activity Sex   \
# Name
# male              Florida  New Smyrna Beach, Volusia County  Surfing    M
# Chucky Luciano    Florida  New Smyrna Beach, Volusia County  Surfing    M
# male              Florida  New Smyrna Beach, Volusia County  Surfing    M
# Rory Angiolella  Victoria                  Thirteenth Beach  Surfing    M
# male             Victoria                       Bells Beach  Surfing    M
#
#                  Age                                 Injury Fatal (Y/N)  \
# Name
# ...

# %%
# Let's save the dataframe of means for later.
# shark_df.to_csv('shark_dataset.csv', index=False)
