# %%
import json
import requests
import os
import 
#

# %%
# Esta es la url utilizada
url = 'https://www.rijksmuseum.nl/api/nl/collection/SK-C-5?key=[API_KEY]&format=json'

# %%
API_KEY = kACoBeWN #

# %%
# Hacemos la primera llamada a la API

response = requests.get('https://www.rijksmuseum.nl/api/nl/collection/SK-C-5?key=kACoBeWN&format=json')
results = response.json()
results
# Out:
# {'elapsedMilliseconds': 153,
#  'artObject': {'links': {'search': 'https://www.rijksmuseum.nl/api/nl/collection'},
#   'id': 'nl-SK-C-5',
#   'priref': '5216',
#   'objectNumber': 'SK-C-5',
#   'language': 'nl',
#   'title': 'Schutters van wijk II onder leiding van kapitein Frans Banninck Cocq, bekend als de ‘Nachtwacht’',
#   'copyrightHolder': None,
#   'webImage': {'guid': 'aa08df9c-0af9-4195-b31b-f578fbe0a4c9',
#    'offsetPercentageX': 50,
#    'offsetPercentageY': 100,
#    'width': 2500,
#    'height': 2034,
#    'url': 'https://lh3.googleusercontent.com/J-mxAE7CPu-DXIOx4QKBtb0GC4ud37da1QK7CzbTIDswmvZHXhLm4Tv2-1H3iBXJWAW_bHm7dMl3j5wv_XiWAg55VOM=s0'},
#   'colors': ['#261808',
#    ' #5E3C14',
#    ' #9C8238',
#    ' #885617',
#    ' #AF9F6B',
#    ' #6C6238',
#    ' #D7CB9E'],
#   'colorsWithNormalization': [{'originalHex': '#261808',
#     'normalizedHex': '#000000'},
#    {'originalHex': ' #5E3C14', 'normalizedHex': '#B35A1F'},
# ...

# %%
test = response.text
print(response.status_code)
print(response.content)
# Out:
# 200
# ...
