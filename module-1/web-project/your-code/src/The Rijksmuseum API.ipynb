# %%
import json
import requests
import os
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from lxml import html
import re

# %%
# Esta es la url utilizada
url = 'https://www.rijksmuseum.nl/api/en/agenda/2019-06-22?key=kACoBeWN&format=json'

# %%
# API_KEY = kACoBeWN #

# %%
# Hacemos la primera llamada a la API

response = requests.get(url)
results = response.json()
results = results['options']
results
# Out:
# [{'links': {'availability': 'https://www.rijksmuseum.nl/api/en/agenda/2019-06-22/exposition/301d0cf5-8e05-e711-80cd-5820b1e20440/availability/b3e73317-dd2d-e811-80cf-5820b1e20448',
#    'web': 'https://www.rijksmuseum.nl/en/groupreservation/deeplink?groupTypeId=5a9f30a3-c83d-459b-92fd-a39f5bb2430c&expositionTypeId=8bdcb1c5-a55d-e711-80cd-5820b1e20440&expositionId=301d0cf5-8e05-e711-80cd-5820b1e20440&expositionPeriodId=b3e73317-dd2d-e811-80cf-5820b1e20448&shortdate=2019-06-22'},
#   'id': 'en-301d0cf5-8e05-e711-80cd-5820b1e20440-b3e73317-dd2d-e811-80cf-5820b1e20448',
#   'lang': 'en',
#   'date': '2019-06-21T22:00:00Z',
#   'period': {'id': 'b3e73317-dd2d-e811-80cf-5820b1e20448',
#    'startDate': '2019-06-22T09:00:00Z',
#    'endDate': '2019-06-22T10:00:00Z',
#    'current': 15,
#    'maximum': 15,
#    'remaining': 0,
#    'code': None,
#    'text': '11:00 - 12:00'},
#   'exposition': {'id': '301d0cf5-8e05-e711-80cd-5820b1e20440',
#    'name': 'Guided Tour Highlights of the Rijksmuseum English',
#    'description': 'Guided Tour Highlights of the Rijksmuseum\r\nLanguage: English\r\n\r\nThe guided tour starts by the Information Desk in the museum Atrium. Please report there prior to the tour.\r\n\r\nWith this reservation, you will not have to queue outside. If you still need to purchase an admission ticket, you can buy a ticket online, or you will have to pass by the ticket counter inside. Therefore, we recommend that you take waiting times into consideration.\r\n',
#    'code': 'E120077A_2017',
#    'controlType': 0,
#    'maxVisitorsPerGroup': 0,
#    'maxVisitorsPerPeriodWeb': 15,
#    'price': {'id': '654a1829-5f67-47a5-99ab-4ee306b42ad7',
#     'calculationType': 2,
#     'amount': 5.0}},
#   'groupType': {'type': 'GroupTypeRef',
#    'guid': '5a9f30a3-c83d-459b-92fd-a39f5bb2430c',
#    'friendlyName': 'Individuals'},
#   'pageRef': {'title': 'Rondleiding Hoogtepunten van het Rijksmuseum',
#    'url': 'https://www.rijksmuseum.nl/nl/nu-in-het-museum/rondleidingen/rondleiding-hoogtepunten-van-het-rijksmuseum'},
#   'expositionType': {'type': 'ExpositionTypeRef',
#    'guid': '8bdcb1c5-a55d-e711-80cd-5820b1e20440',
#    'friendlyName': 'Guided tours adults'}},
#  {'links': {'availability': 'https://www.rijksmuseum.nl/api/en/agenda/2019-06-22/exposition/301d0cf5-8e05-e711-80cd-5820b1e20440/availability/a4462c35-dd2d-e811-80cf-5820b1e20448',
#    'web': 'https://www.rijksmuseum.nl/en/groupreservation/deeplink?groupTypeId=5a9f30a3-c83d-459b-92fd-a39f5bb2430c&expositionTypeId=8bdcb1c5-a55d-e711-80cd-5820b1e20440&expositionId=301d0cf5-8e05-e711-80cd-5820b1e20440&expositionPeriodId=a4462c35-dd2d-e811-80cf-5820b1e20448&shortdate=2019-06-22'},
#   'id': 'en-301d0cf5-8e05-e711-80cd-5820b1e20440-a4462c35-dd2d-e811-80cf-5820b1e20448',
#   'lang': 'en',
#   'date': '2019-06-21T22:00:00Z',
#   'period': {'id': 'a4462c35-dd2d-e811-80cf-5820b1e20448',
#    'startDate': '2019-06-22T10:00:00Z',
#    'endDate': '2019-06-22T11:00:00Z',
#    'current': 15,
#    'maximum': 15,
#    'remaining': 0,
#    'code': None,
#    'text': '12:00 - 13:00'},
#   'exposition': {'id': '301d0cf5-8e05-e711-80cd-5820b1e20440',
#    'name': 'Guided Tour Highlights of the Rijksmuseum English',
#    'description': 'Guided Tour Highlights of the Rijksmuseum\r\nLanguage: English\r\n\r\nThe guided tour starts by the Information Desk in the museum Atrium. Please report there prior to the tour.\r\n\r\nWith this reservation, you will not have to queue outside. If you still need to purchase an admission ticket, you can buy a ticket online, or you will have to pass by the ticket counter inside. Therefore, we recommend that you take waiting times into consideration.\r\n',
#    'code': 'E120077A_2017',
#    'controlType': 0,
#    'maxVisitorsPerGroup': 0,
#    'maxVisitorsPerPeriodWeb': 15,
#    'price': {'id': '654a1829-5f67-47a5-99ab-4ee306b42ad7',
#     'calculationType': 2,
#     'amount': 5.0}},
#   'groupType': {'type': 'GroupTypeRef',
#    'guid': '5a9f30a3-c83d-459b-92fd-a39f5bb2430c',
#    'friendlyName': 'Individuals'},
#   'pageRef': {'title': 'Rondleiding Hoogtepunten van het Rijksmuseum',
#    'url': 'https://www.rijksmuseum.nl/nl/nu-in-het-museum/rondleidingen/rondleiding-hoogtepunten-van-het-rijksmuseum'},
#   'expositionType': {'type': 'ExpositionTypeRef',
#    'guid': '8bdcb1c5-a55d-e711-80cd-5820b1e20440',
#    'friendlyName': 'Guided tours adults'}},
#  {'links': {'availability': 'https://www.rijksmuseum.nl/api/en/agenda/2019-06-22/exposition/301d0cf5-8e05-e711-80cd-5820b1e20440/availability/b8d23b41-dd2d-e811-80cf-5820b1e20448',
#    'web': 'https://www.rijksmuseum.nl/en/groupreservation/deeplink?groupTypeId=5a9f30a3-c83d-459b-92fd-a39f5bb2430c&expositionTypeId=8bdcb1c5-a55d-e711-80cd-5820b1e20440&expositionId=301d0cf5-8e05-e711-80cd-5820b1e20440&expositionPeriodId=b8d23b41-dd2d-e811-80cf-5820b1e20448&shortdate=2019-06-22'},
#   'id': 'en-301d0cf5-8e05-e711-80cd-5820b1e20440-b8d23b41-dd2d-e811-80cf-5820b1e20448',
#   'lang': 'en',
#   'date': '2019-06-21T22:00:00Z',
#   'period': {'id': 'b8d23b41-dd2d-e811-80cf-5820b1e20448',
#    'startDate': '2019-06-22T12:00:00Z',
#    'endDate': '2019-06-22T13:00:00Z',
#    'current': 11,
#    'maximum': 15,
#    'remaining': 4,
#    'code': None,
#    'text': '14:00 - 15:00'},
#   'exposition': {'id': '301d0cf5-8e05-e711-80cd-5820b1e20440',
#    'name': 'Guided Tour Highlights of the Rijksmuseum English',
#    'description': 'Guided Tour Highlights of the Rijksmuseum\r\nLanguage: English\r\n\r\nThe guided tour starts by the Information Desk in the museum Atrium. Please report there prior to the tour.\r\n\r\nWith this reservation, you will not have to queue outside. If you still need to purchase an admission ticket, you can buy a ticket online, or you will have to pass by the ticket counter inside. Therefore, we recommend that you take waiting times into consideration.\r\n',
#    'code': 'E120077A_2017',
#    'controlType': 0,
#    'maxVisitorsPerGroup': 0,
#    'maxVisitorsPerPeriodWeb': 15,
#    'price': {'id': '654a1829-5f67-47a5-99ab-4ee306b42ad7',
#     'calculationType': 2,
#     'amount': 5.0}},
#   'groupType': {'type': 'GroupTypeRef',
#    'guid': '5a9f30a3-c83d-459b-92fd-a39f5bb2430c',
#    'friendlyName': 'Individuals'},
#   'pageRef': {'title': 'Rondleiding Hoogtepunten van het Rijksmuseum',
#    'url': 'https://www.rijksmuseum.nl/nl/nu-in-het-museum/rondleidingen/rondleiding-hoogtepunten-van-het-rijksmuseum'},
#   'expositionType': {'type': 'ExpositionTypeRef',
#    'guid': '8bdcb1c5-a55d-e711-80cd-5820b1e20440',
#    'friendlyName': 'Guided tours adults'}},
#  {'links': {'availability': 'https://www.rijksmuseum.nl/api/en/agenda/2019-06-22/exposition/301d0cf5-8e05-e711-80cd-5820b1e20440/availability/f5b83b29-dd2d-e811-80cf-5820b1e20448',
#    'web': 'https://www.rijksmuseum.nl/en/groupreservation/deeplink?groupTypeId=5a9f30a3-c83d-459b-92fd-a39f5bb2430c&expositionTypeId=8bdcb1c5-a55d-e711-80cd-5820b1e20440&expositionId=301d0cf5-8e05-e711-80cd-5820b1e20440&expositionPeriodId=f5b83b29-dd2d-e811-80cf-5820b1e20448&shortdate=2019-06-22'},
#   'id': 'en-301d0cf5-8e05-e711-80cd-5820b1e20440-f5b83b29-dd2d-e811-80cf-5820b1e20448',
#   'lang': 'en',
#   'date': '2019-06-21T22:00:00Z',
#   'period': {'id': 'f5b83b29-dd2d-e811-80cf-5820b1e20448',
#    'startDate': '2019-06-22T13:00:00Z',
#    'endDate': '2019-06-22T14:00:00Z',
#    'current': 14,
#    'maximum': 15,
#    'remaining': 1,
#    'code': None,
#    'text': '15:00 - 16:00'},
#   'exposition': {'id': '301d0cf5-8e05-e711-80cd-5820b1e20440',
#    'name': 'Guided Tour Highlights of the Rijksmuseum English',
#    'description': 'Guided Tour Highlights of the Rijksmuseum\r\nLanguage: English\r\n\r\nThe guided tour starts by the Information Desk in the museum Atrium. Please report there prior to the tour.\r\n\r\nWith this reservation, you will not have to queue outside. If you still need to purchase an admission ticket, you can buy a ticket online, or you will have to pass by the ticket counter inside. Therefore, we recommend that you take waiting times into consideration.\r\n',
#    'code': 'E120077A_2017',
#    'controlType': 0,
#    'maxVisitorsPerGroup': 0,
#    'maxVisitorsPerPeriodWeb': 15,
#    'price': {'id': '654a1829-5f67-47a5-99ab-4ee306b42ad7',
#     'calculationType': 2,
#     'amount': 5.0}},
#   'groupType': {'type': 'GroupTypeRef',
#    'guid': '5a9f30a3-c83d-459b-92fd-a39f5bb2430c',
#    'friendlyName': 'Individuals'},
#   'pageRef': {'title': 'Rondleiding Hoogtepunten van het Rijksmuseum',
#    'url': 'https://www.rijksmuseum.nl/nl/nu-in-het-museum/rondleidingen/rondleiding-hoogtepunten-van-het-rijksmuseum'},
#   'expositionType': {'type': 'ExpositionTypeRef',
#    'guid': '8bdcb1c5-a55d-e711-80cd-5820b1e20440',
#    'friendlyName': 'Guided tours adults'}}]

# %%
data = pd.DataFrame(results)
data
# Out:
#                    date                                         exposition  \
# 0  2019-06-21T22:00:00Z  {'id': '301d0cf5-8e05-e711-80cd-5820b1e20440',...
# 1  2019-06-21T22:00:00Z  {'id': '301d0cf5-8e05-e711-80cd-5820b1e20440',...
# 2  2019-06-21T22:00:00Z  {'id': '301d0cf5-8e05-e711-80cd-5820b1e20440',...
# 3  2019-06-21T22:00:00Z  {'id': '301d0cf5-8e05-e711-80cd-5820b1e20440',...
#
#                                       expositionType  \
# 0  {'type': 'ExpositionTypeRef', 'guid': '8bdcb1c...
# 1  {'type': 'ExpositionTypeRef', 'guid': '8bdcb1c...
# 2  {'type': 'ExpositionTypeRef', 'guid': '8bdcb1c...
# 3  {'type': 'ExpositionTypeRef', 'guid': '8bdcb1c...
#
#                                            groupType  \
# 0  {'type': 'GroupTypeRef', 'guid': '5a9f30a3-c83...
# 1  {'type': 'GroupTypeRef', 'guid': '5a9f30a3-c83...
# 2  {'type': 'GroupTypeRef', 'guid': '5a9f30a3-c83...
# 3  {'type': 'GroupTypeRef', 'guid': '5a9f30a3-c83...
#
#                                                   id lang  \
# 0  en-301d0cf5-8e05-e711-80cd-5820b1e20440-b3e733...   en
# 1  en-301d0cf5-8e05-e711-80cd-5820b1e20440-a4462c...   en
# 2  en-301d0cf5-8e05-e711-80cd-5820b1e20440-b8d23b...   en
# 3  en-301d0cf5-8e05-e711-80cd-5820b1e20440-f5b83b...   en
#
#                                                links  \
# 0  {'availability': 'https://www.rijksmuseum.nl/a...
# 1  {'availability': 'https://www.rijksmuseum.nl/a...
# 2  {'availability': 'https://www.rijksmuseum.nl/a...
# 3  {'availability': 'https://www.rijksmuseum.nl/a...
#
#                                              pageRef  \
# 0  {'title': 'Rondleiding Hoogtepunten van het Ri...
# 1  {'title': 'Rondleiding Hoogtepunten van het Ri...
# 2  {'title': 'Rondleiding Hoogtepunten van het Ri...
# 3  {'title': 'Rondleiding Hoogtepunten van het Ri...
#
#                                               period
# 0  {'id': 'b3e73317-dd2d-e811-80cf-5820b1e20448',...
# 1  {'id': 'a4462c35-dd2d-e811-80cf-5820b1e20448',...
# 2  {'id': 'b8d23b41-dd2d-e811-80cf-5820b1e20448',...
# 3  {'id': 'f5b83b29-dd2d-e811-80cf-5820b1e20448',...
