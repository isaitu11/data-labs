# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=8, random_state=0).fit(X)

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X, kmeans.labels_, metric='euclidean')
score
# Out:
# 0.5361427462305504

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(X)
y_pred = kmeans.predict(X)
score = silhouette_score(X, y_pred, metric='euclidean')
score
# Out:
# 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)
y_pred = kmeans.predict(X)
score = silhouette_score(X, y_pred, metric='euclidean')
score
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,12),metric='silhouette')

visualizer.fit(X)
visualizer.poof()

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,12),metric='distortion')
visualizer.fit(X)
visualizer.poof()

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,12),metric='calinski_harabaz')
visualizer.fit(X)
visualizer.poof()
# Out:
# ---------------------------------------------------------------------------
# YellowbrickValueError                     Traceback (most recent call last)
# <ipython-input-9-32ce285cdd31> in <module>
#       1 model = KMeans()
# ----> 2 visualizer = KElbowVisualizer(model, k=(2,12),metric='calinski_harabaz')
#       3 visualizer.fit(X)
#       4 visualizer.poof()
#
# /usr/local/lib/python3.7/site-packages/yellowbrick/cluster/elbow.py in __init__(self, model, ax, k, metric, timings, locate_elbow, **kwargs)
#     250         if metric not in KELBOW_SCOREMAP:
#     251             raise YellowbrickValueError(
# --> 252                 "'{}' is not a defined metric "
#     253                 "use one of distortion, silhouette, or calinski_harabasz"
#     254             )
#
# YellowbrickValueError: '{}' is not a defined metric use one of distortion, silhouette, or calinski_harabasz

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn.cluster import AgglomerativeClustering
clustering = AgglomerativeClustering().fit(X)
score = silhouette_score(X, clustering.labels_, metric='euclidean')
print(score)

model = AgglomerativeClustering()
visualizer = KElbowVisualizer(model, k=(2,12),metric='silhouette')
visualizer.fit(X)
visualizer.poof()
# Out:
# 0.6587292996216916

# %%
model = AgglomerativeClustering()
visualizer = KElbowVisualizer(model, k=(2,12),metric='distortion')
visualizer.fit(X)
visualizer.poof()

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
import seaborn as sns
sns.set(style="ticks")
#usamos Kmeans  3 clusters
X['labels']=kmeans.labels_
sns.pairplot(X, hue='labels')
# Out:
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.
